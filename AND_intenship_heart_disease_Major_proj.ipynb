# %%
# importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#loading the dataset
heart_data = pd.read_csv('/content/heart.csv')

# %%
# top 5 rows
heart_data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# bot 5 rows
heart_data.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %% [markdown]
# ### **EDA**

# %%
# no. of rows and columns
heart_data.shape
# Out:
# (918, 12)

# %%
heart_data.size
# Out:
# 11016

# %%
heart_data.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
heart_data.ndim
# Out:
# 2

# %%
# getting some info about the data
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
# statistical measures about the data
heart_data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
# checking for missing values
heart_data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
# checking for duplicates
heart_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # converting data

# %%
heart_data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le=LabelEncoder()

# %%
le.fit(heart_data['Sex'])
heart_data['Sex'] = le.transform(heart_data['Sex'])

# %%
le.fit(heart_data['RestingECG'])
heart_data['RestingECG'] = le.transform(heart_data['RestingECG'])

# %%
le.fit(heart_data['ExerciseAngina'])
heart_data['ExerciseAngina'] = le.transform(heart_data['ExerciseAngina'])

# %%
le.fit(heart_data['ST_Slope'])
heart_data['ST_Slope'] = le.transform(heart_data['ST_Slope'])

# %%
le.fit(heart_data['ChestPainType'])
heart_data['ChestPainType'] = le.transform(heart_data['ChestPainType'])

# %%
heart_data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
# checking the distribution of Target Variable
heart_data['HeartDisease'].value_counts()
# Out:
# 1    508
# 0    410
# Name: HeartDisease, dtype: int64

# %% [markdown]
# 1 --> Defective Heart
#
# 0 --> Healthy Heart

# %% [markdown]
# Splitting the Features and Target

# %%
X = heart_data.drop(columns='HeartDisease', axis=1)
Y = heart_data['HeartDisease']

# %% [markdown]
# Splitting the Data into Training data & Test Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.7, random_state=40)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (642, 11)
# (276, 11)
# (642,)
# (276,)

# %% [markdown]
# ### **Model building**

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression

# %%
LR_model = LogisticRegression()

# %%
LR_model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model evaluation

# %%
# accuracy on training data
X_train_prediction = LR_model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

print(training_data_accuracy)
# Out:
# 0.8598130841121495

# %%
# accuracy on test data
X_test_prediction = LR_model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

print(test_data_accuracy)
# Out:
# 0.8405797101449275

# %%
# classification_report
print(classification_report(X_test_prediction, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81       118
#            1       0.86      0.87      0.86       158
#
#     accuracy                           0.84       276
#    macro avg       0.84      0.84      0.84       276
# weighted avg       0.84      0.84      0.84       276

# %%
# confusion_matrix
print(confusion_matrix(X_test_prediction, Y_test))
# Out:
# [[ 95  23]
#  [ 21 137]]

# %% [markdown]
# ### **Predictive System**

# %%
input_data = (40,1,1,140,289,0,1,172,0,0.0,2)


input_data_as_numpy_array= np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = LR_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have Heart Failure disease ')
else:
  print('The Person has Heart Failure Disease')
# Out:
# [0]
# The Person does not have Heart Failure disease

# %%
input_data = (48,0,0,138,214,0,1,108,1,1.5,1)


input_data_as_numpy_array= np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = LR_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have Heart Failure disease ')
else:
  print('The Person has Heart Failure Disease')
# Out:
# [1]
# The Person has Heart Failure Disease

# %% [markdown]
# ### **Visualization**

# %%
# Scatter plot for age vs. predicted heart disease risk
plt.figure(figsize=(8, 6))
plt.scatter(X_test['Age'], X_test_prediction, c=Y_test, cmap='coolwarm', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Predicted Heart Disease Risk')
plt.title('Age vs. Predicted Heart Disease Risk')
plt.colorbar(label='Actual Heart Disease (0: No, 1: Yes)')
plt.grid(True)
plt.show()

# %%
# As age increases, the predicted risk tends to rise.
# This aligns with our understanding that older individuals are more
#  susceptible to heart-related issues.
